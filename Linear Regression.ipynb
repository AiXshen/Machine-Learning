# %%
#LINEAR REGRESSION USING GRADIENT

import numpy as np
class LinearRegression:
    def __init__ (self,learning_rate = 0.01,iterations = 1000):
        self.lr = learning_rate
        self.iterations = iterations
        self.weights = None
        self.bias = None

    def fit(self,X,y):
        samples , features = X.shape
        self.weights = np.zeros(features)
        self.bias = 0
        for i in range (self.iterations):
            y_predicted = np.dot(X, self.weights) + self.bias

            dw = 1/samples * np.dot(X.T ,(y_predicted - y))
            db = 1/samples * np.sum( y_predicted - y)

            self.weights = self.weights - self.lr *dw
            self.bias = self.bias - self.lr *db

    def predict ( self , X) :
            y_predicted = np.dot(X, self.weights)  + self.bias
            return y_predicted;
# Out:
# C:\Users\shubh\PycharmProjects\ALLLIBRARIES\.venv\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 from keras.src.legacy.backend import bias_add
# ----> 3 from magic.compat import none_magic
#       4 from matplotlib import pyplot as plt
#       5                                              #####DATA#####
#       6 #consider following data of Time spent Studying vs Marks scored (Hours vs Marks)_
#
# File ~\PycharmProjects\ALLLIBRARIES\.venv\Lib\site-packages\magic\__init__.py:209
#     206     return m.from_descriptor(fd)
#     208 from . import loader
# --> 209 libmagic = loader.load_lib()
#     211 magic_t = ctypes.c_void_p
#     214 def errorcheck_null(result, func, args):
#
# File ~\PycharmProjects\ALLLIBRARIES\.venv\Lib\site-packages\magic\loader.py:49, in load_lib()
#      46     pass
#      47 else:
#      48   # It is better to raise an ImportError since we are importing magic module
# ---> 49   raise ImportError('failed to find libmagic.  Check your installation')
#
# ImportError: failed to find libmagic.  Check your installation
